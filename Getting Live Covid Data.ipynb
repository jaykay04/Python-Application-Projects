# %%
pip install covid
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 2.3 MB 895 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 1.2 MB/s eta 0:00:01
# ...
#   Created wheel for covid: filename=covid-2.4.0-py3-none-any.whl size=9609 sha256=45761b5ab765a2a13324ac04acba668ea94e47a14ac852d641a96f0a433c7010
#   Stored in directory: /Users/jaykay/Library/Caches/pip/wheels/fe/7b/79/ab19bf5c3a2e88196f6e2a01fe850d89ff391c39f47e1a4553
# Successfully built covid
# ...
#   Attempting uninstall: click
#     Found existing installation: Click 7.0
#     Uninstalling Click-7.0:
#       Successfully uninstalled Click-7.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from covid import Covid

# %%
cov=Covid()
covid_data=cov.get_data()
covid_data
# Out:
# [{'id': '178',
#   'country': 'US',
#   'confirmed': 20573505,
#   'active': 20222228,
#   'deaths': 351277,
#   'recovered': None,
#   'latitude': 40.0,
#   'longitude': -100.0,
#   'last_update': 1609708989000},
#  {'id': '80',
#   'country': 'India',
#   'confirmed': 10323965,
#   'active': 247220,
#   'deaths': 149435,
#   'recovered': 9927310,
#   'latitude': 20.593684,
#   'longitude': 78.96288,
#   'last_update': 1609708989000},
#  {'id': '24',
#   'country': 'Brazil',
#   'confirmed': 7716405,
#   'active': 619897,
#   'deaths': 195725,
#   'recovered': 6900783,
#   'latitude': -14.235,
#   'longitude': -51.9253,
#   'last_update': 1609708989000},
#  {'id': '142',
#   'country': 'Russia',
#   'confirmed': 3203743,
#   'active': 554076,
#   'deaths': 57730,
#   'recovered': 2591937,
#   'latitude': 61.524,
#   'longitude': 105.3188,
#   'last_update': 1609708989000},
#  {'id': '63',
#   'country': 'France',
#   'confirmed': 2712975,
#   'active': 2446503,
#   'deaths': 65164,
# ...

# %%
#lets get data for a particular country
cov.get_status_by_country_name('Nigeria')
# Out:
# {'id': '128',
#  'country': 'Nigeria',
#  'confirmed': 89163,
#  'active': 13072,
#  'deaths': 1302,
#  'recovered': 74789,
#  'latitude': 9.082,
#  'longitude': 8.6753,
#  'last_update': 1609708989000}

# %%
cov.get_status_by_country_id(18)
# Out:
# {'id': '18',
#  'country': 'Belize',
#  'confirmed': 10807,
#  'active': 608,
#  'deaths': 249,
#  'recovered': 9950,
#  'latitude': 17.1899,
#  'longitude': -88.4976,
#  'last_update': 1609708989000}
